# %%
# GET /hello/world
print("I'm cell #1")
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1498639906082_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hn1-manish.zkrb5x5fyk1erc1btosidz1cra.gx.internal.cloudapp.net:8088/proxy/application_1498639906082_0004/">Link</a></td><td><a target="_blank" href="http://10.0.0.12:30060/node/containerlogs/container_1498639906082_0004_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# I'm cell #1
